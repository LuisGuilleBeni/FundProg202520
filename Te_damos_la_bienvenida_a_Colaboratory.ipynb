# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisGuilleBeni/FundProg202520/blob/main/Te_damos_la_bienvenida_a_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# FUNDAMENTOS DE PROGRAMACION
#
# EVALUACION 3 : ESTRUCTURA SECUENCIALES
#
# LUIS GUILLERMO BENITEZ RUIZ
#
# luis.benitezr@upb.edu.co
#
# FECHA: 19 / 09 2025

# %%
# Programa para calcular propina, impuesto y total
costo_comida = float(input("Ingrese el costo de la comida: $"))

propina = costo_comida * 0.15
impuesto = costo_comida * 0.07
total = costo_comida + propina + impuesto

print(f"\nCosto de la comida: ${costo_comida:.2f}")
print(f"Propina (15%): ${propina:.2f}")
print(f"Impuesto (7%): ${impuesto:.2f}")
print(f"Total a pagar: ${total:.2f}")
# Out:
# Ingrese el costo de la comida: $200
#
# Costo de la comida: $200.00
# Propina (15%): $30.00
# Impuesto (7%): $14.00
# Total a pagar: $244.00

# %% [markdown]
# INICIO
#     DEFINIR costo_comida, propina, impuesto, total COMO real
#
#     ESCRIBIR "Ingrese el costo de la comida: "
#     LEER costo_comida
#
#     propina = costo_comida * 0.15
#     impuesto = costo_comida * 0.07
#     total = costo_comida + propina + impuesto
#
#     ESCRIBIR "Costo de la comida: $" + costo_comida
#     ESCRIBIR "Propina (15%): $" + propina
#     ESCRIBIR "Impuesto (7%): $" + impuesto
#     ESCRIBIR "Total a pagar: $" + total
# FIN
